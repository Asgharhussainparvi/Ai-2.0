# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Read the stock prices data using pandas
stock_df = pd.read_csv("usd_pkr.csv")
stock_df["Date"] = pd.to_datetime(stock_df["Date"])
stock_df
# Out:
#            Date    Price     Open     High     Low Change %
# 0    2023-03-16  278.750  282.875  283.250  278.75   -1.50%
# 1    2023-03-15  283.000  282.125  283.375  279.50    2.30%
# 2    2023-03-14  276.650  282.125  282.450  278.63   -1.79%
# 3    2023-03-13  281.700  277.250  282.475  277.25    0.59%
# 4    2023-03-10  280.050  281.000  283.150  275.75    0.92%
# ...         ...      ...      ...      ...     ...      ...
# 6811 1999-06-11   51.745   51.740   51.745   51.74    0.09%
# 6812 1999-06-10   51.700   51.650   51.700   51.65   -0.06%
# 6813 1999-06-09   51.730   51.710   51.730   51.71    0.04%
# 6814 1999-06-08   51.710   51.670   51.710   51.67    0.12%
# 6815 1999-06-07   51.650   51.600   51.650   51.60   -0.10%
#
# [6816 rows x 6 columns]

# %%
stock_df.head(10)
# Out:
#         Date   Price     Open     High     Low Change %
# 0 2023-03-16  278.75  282.875  283.250  278.75   -1.50%
# 1 2023-03-15  283.00  282.125  283.375  279.50    2.30%
# 2 2023-03-14  276.65  282.125  282.450  278.63   -1.79%
# 3 2023-03-13  281.70  277.250  282.475  277.25    0.59%
# 4 2023-03-10  280.05  281.000  283.150  275.75    0.92%
# 5 2023-03-09  277.50  279.125  284.000  275.75    0.00%
# 6 2023-03-08  277.50  277.125  279.375  274.88    0.36%
# 7 2023-03-07  276.50  276.000  278.250  272.50    0.47%
# 8 2023-03-06  275.20  278.410  279.365  272.50   -0.11%
# 9 2023-03-03  275.50  282.500  282.950  274.75   -2.10%

# %%
stock_df.tail(10)
# Out:
#            Date   Price   Open    High    Low Change %
# 6806 1999-06-18  51.855  51.83  51.855  51.83    0.01%
# 6807 1999-06-17  51.850  51.80  51.850  51.80   -0.02%
# 6808 1999-06-16  51.858  51.82  51.858  51.82    0.01%
# 6809 1999-06-15  51.855  51.83  51.855  51.83   -0.04%
# 6810 1999-06-14  51.875  51.85  51.875  51.85    0.25%
# 6811 1999-06-11  51.745  51.74  51.745  51.74    0.09%
# 6812 1999-06-10  51.700  51.65  51.700  51.65   -0.06%
# 6813 1999-06-09  51.730  51.71  51.730  51.71    0.04%
# 6814 1999-06-08  51.710  51.67  51.710  51.67    0.12%
# 6815 1999-06-07  51.650  51.60  51.650  51.60   -0.10%

# %%
stock_df.shape
# Out:
# (6816, 6)

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6816 entries, 0 to 6815
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6816 non-null   datetime64[ns]
#  1   Price     6816 non-null   float64
#  2   Open      6816 non-null   float64
#  3   High      6816 non-null   float64
#  4   Low       6816 non-null   float64
#  5   Change %  6816 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 319.6+ KB

# %%
stock_df.describe()
# Out:
#                                 Date        Price         Open         High  \
# count                           6816  6816.000000  6816.000000  6816.000000
# mean   2011-10-09 17:51:32.957746432    97.637774    97.584464    97.923917
# min              1999-06-07 00:00:00    51.175000    51.150000    51.175000
# 25%              2005-12-20 18:00:00    60.498750    60.400000    60.540000
# 50%              2012-04-09 12:00:00    90.870000    90.770000    90.950000
# 75%              2017-08-12 06:00:00   105.500000   105.460000   105.571250
# max              2023-03-16 00:00:00   283.000000   282.875000   284.000000
# std                              NaN    41.561494    41.615018    41.850771
#
#                Low
# count  6816.000000
# mean     97.303022
# min      51.150000
# 25%      60.350000
# 50%      90.675000
# 75%     105.390000
# max     279.500000
# std      41.322500

# %%
stock_df.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Change %            object
# dtype: object

# %%
stock_df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Change %'], dtype='object')

# %%
obj = stock_df.select_dtypes(include=['object'])
obj
# Out:
#      Change %
# 0      -1.50%
# 1       2.30%
# 2      -1.79%
# 3       0.59%
# 4       0.92%
# ...       ...
# 6811    0.09%
# 6812   -0.06%
# 6813    0.04%
# 6814    0.12%
# 6815   -0.10%
#
# [6816 rows x 1 columns]

# %%
str = stock_df.select_dtypes(exclude=['number'])
str
# Out:
#            Date Change %
# 0    2023-03-16   -1.50%
# 1    2023-03-15    2.30%
# 2    2023-03-14   -1.79%
# 3    2023-03-13    0.59%
# 4    2023-03-10    0.92%
# ...         ...      ...
# 6811 1999-06-11    0.09%
# 6812 1999-06-10   -0.06%
# 6813 1999-06-09    0.04%
# 6814 1999-06-08    0.12%
# 6815 1999-06-07   -0.10%
#
# [6816 rows x 2 columns]

# %%
stock_df[["Date","Price"]].tail(5)
# Out:
#            Date   Price
# 6811 1999-06-11  51.745
# 6812 1999-06-10  51.700
# 6813 1999-06-09  51.730
# 6814 1999-06-08  51.710
# 6815 1999-06-07  51.650

# %%
stock_df.loc[1:10,["Price"]]
# Out:
#      Price
# 1   283.00
# 2   276.65
# 3   281.70
# 4   280.05
# 5   277.50
# 6   277.50
# 7   276.50
# 8   275.20
# 9   275.50
# 10  281.40

# %%
X = stock_df["Date"]
Y = stock_df["Price"]
plt.plot(X,Y)
plt.ylabel("Price")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
corr =stock_df[['Date','Price','Open','High','Low']].corr()
corr
# Out:
#            Date     Price      Open      High       Low
# Date   1.000000  0.892957  0.893216  0.891725  0.894221
# Price  0.892957  1.000000  0.999887  0.999937  0.999874
# Open   0.893216  0.999887  1.000000  0.999883  0.999918
# High   0.891725  0.999937  0.999883  1.000000  0.999800
# Low    0.894221  0.999874  0.999918  0.999800  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Extract time-based features
stock_df['Year'] = stock_df['Date'].dt.year
stock_df['Month'] = stock_df['Date'].dt.month
stock_df['Day'] = stock_df['Date'].dt.day
stock_df['Weekday'] = stock_df['Date'].dt.weekday

# %%
monthly_inc = stock_df.groupby(['Month'])['Price'].sum().reset_index()
monthly_inc
# Out:
#     Month      Price
# 0       1  57635.458
# 1       2  54032.065
# 2       3  56718.201
# 3       4  52070.904
# 4       5  53246.689
# 5       6  53971.875
# 6       7  56021.534
# 7       8  56362.888
# 8       9  55507.262
# 9      10  56723.771
# 10     11  55381.538
# 11     12  57826.882

# %%
stock_df.head(3)
# Out:
#         Date   Price     Open     High     Low Change %  Year  Month  Day  \
# 0 2023-03-16  278.75  282.875  283.250  278.75   -1.50%  2023      3   16
# 1 2023-03-15  283.00  282.125  283.375  279.50    2.30%  2023      3   15
# 2 2023-03-14  276.65  282.125  282.450  278.63   -1.79%  2023      3   14
#
#    Weekday
# 0        3
# 1        2
# 2        1

# %%
avg_high = stock_df['High'].astype('float').mean()
# Show the plot
plt.show()
print(avg_high)
# Out:
# 97.9239169600939

# %%
stock_df.isnull().sum()
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# Year        0
# Month       0
# Day         0
# Weekday     0
# dtype: int64

# %%
stock_df.loc[stock_df['High']> avg_high]
# Out:
#            Date   Price     Open     High     Low Change %  Year  Month  Day  \
# 0    2023-03-16  278.75  282.875  283.250  278.75   -1.50%  2023      3   16
# 1    2023-03-15  283.00  282.125  283.375  279.50    2.30%  2023      3   15
# 2    2023-03-14  276.65  282.125  282.450  278.63   -1.79%  2023      3   14
# 3    2023-03-13  281.70  277.250  282.475  277.25    0.59%  2023      3   13
# 4    2023-03-10  280.05  281.000  283.150  275.75    0.92%  2023      3   10
# ...         ...     ...      ...      ...     ...      ...   ...    ...  ...
# 3147 2013-02-07   97.92   97.800   97.960   97.70    0.02%  2013      2    7
# 3190 2012-12-19   97.80   97.850   98.010   97.65   -0.15%  2012     12   19
# 3191 2012-12-18   97.95   98.050   98.260   97.80   -0.20%  2012     12   18
# 3192 2012-12-17   98.15   97.600   98.340   97.60    0.46%  2012     12   17
# 3194 2012-12-14   97.70   97.400   98.050   97.40    0.15%  2012     12   14
#
#       Weekday
# 0           3
# ...

# %%
stock_df.replace(["?","$","%","@"],np.nan,inplace=True)
stock_df.head()
# Out:
#         Date   Price     Open     High     Low Change %  Year  Month  Day  \
# 0 2023-03-16  278.75  282.875  283.250  278.75   -1.50%  2023      3   16
# 1 2023-03-15  283.00  282.125  283.375  279.50    2.30%  2023      3   15
# 2 2023-03-14  276.65  282.125  282.450  278.63   -1.79%  2023      3   14
# 3 2023-03-13  281.70  277.250  282.475  277.25    0.59%  2023      3   13
# 4 2023-03-10  280.05  281.000  283.150  275.75    0.92%  2023      3   10
#
#    Weekday
# 0        3
# 1        2
# 2        1
# 3        0
# 4        4

# %%
stock_df.drop(columns=['Order Day','Order Year','Order Month','Order Weekday'],inplace=True)
stock_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 stock_df.drop(columns=['Order Day','Order Year','Order Month','Order Weekday'],inplace=True)
#       2 stock_df.head()
#
# File c:\Users\1212a\OneDrive\Desktop\Ai 2.0\Numpy\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %%
stock_df.head(3)
# Out:
#         Date   Price     Open     High     Low Change %  Year  Month  Day  \
# 0 2023-03-16  278.75  282.875  283.250  278.75   -1.50%  2023      3   16
# 1 2023-03-15  283.00  282.125  283.375  279.50    2.30%  2023      3   15
# 2 2023-03-14  276.65  282.125  282.450  278.63   -1.79%  2023      3   14
#
#    Weekday
# 0        3
# 1        2
# 2        1

# %%
stock_df["Change %"] = stock_df["Change %"].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 stock_df["Change %"] = stock_df["Change %"].astype('float')
#
# File c:\Users\1212a\OneDrive\Desktop\Ai 2.0\Numpy\.venv\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\1212a\OneDrive\Desktop\Ai 2.0\Numpy\.venv\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
plt.figure(figsize=(12, 5))
stock_df.hist(bins=10, edgecolor='black', figsize=(12, 10))
plt.suptitle('Distribution of Rates', fontsize=16)
plt.show()

# %%
# PDF of all
plt.figure(figsize=(6, 4))
sns.kdeplot(stock_df['Price'], fill=True, color='blue', label='Price')
sns.kdeplot(stock_df['High'], fill=True, color='red', label='High')
sns.kdeplot(stock_df['Low'], fill=True, color='green', label='Low')

plt.title('Probability Density Function of USD price', fontsize=14)
plt.xlabel('Score')
plt.ylabel('Density')
plt.xticks(np.arange(20, 300, 50))
plt.legend()
plt.show()

# %%
stock_df.head()
# Out:
#         Date   Price     Open     High     Low Change %  Year  Month  Day  \
# 0 2023-03-16  278.75  282.875  283.250  278.75   -1.50%  2023      3   16
# 1 2023-03-15  283.00  282.125  283.375  279.50    2.30%  2023      3   15
# 2 2023-03-14  276.65  282.125  282.450  278.63   -1.79%  2023      3   14
# 3 2023-03-13  281.70  277.250  282.475  277.25    0.59%  2023      3   13
# 4 2023-03-10  280.05  281.000  283.150  275.75    0.92%  2023      3   10
#
#    Weekday
# 0        3
# 1        2
# 2        1
# 3        0
# 4        4

# %%
stock_df.describe()
# Out:
#                                 Date        Price         Open         High  \
# count                           6816  6816.000000  6816.000000  6816.000000
# mean   2011-10-09 17:51:32.957746432    97.637774    97.584464    97.923917
# min              1999-06-07 00:00:00    51.175000    51.150000    51.175000
# 25%              2005-12-20 18:00:00    60.498750    60.400000    60.540000
# 50%              2012-04-09 12:00:00    90.870000    90.770000    90.950000
# 75%              2017-08-12 06:00:00   105.500000   105.460000   105.571250
# max              2023-03-16 00:00:00   283.000000   282.875000   284.000000
# std                              NaN    41.561494    41.615018    41.850771
#
#                Low         Year        Month          Day      Weekday
# count  6816.000000  6816.000000  6816.000000  6816.000000  6816.000000
# mean     97.303022  2011.271567     6.532424    15.740023     2.291080
# min      51.150000  1999.000000     1.000000     1.000000     0.000000
# ...

# %%
# Calculate mean and standard deviation
mean_math = stock_df['Price'].mean()
std_math = stock_df['Price'].std()
print(f"Mean: {mean_math}, Standard Deviation: {std_math}")

# Generate x values for Gaussian curve
x = np.linspace(stock_df['Price'].min(), stock_df['Price'].max(), 100)

# Compute Gaussian distribution
gaussian = (1 / (std_math * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean_math) / std_math) ** 2)
plt.figure(figsize=(7, 4))
plt.plot(x, gaussian, color='red', linewidth=2, label='Gaussian Curve')
plt.title('Gaussian Distribution of Price', fontsize=14)
plt.xlabel('Math Score')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Mean: 97.63777391431925, Standard Deviation: 41.561494220282064

# %%
plt.figure(figsize=(7, 4))
sns.histplot(stock_df['Price'], 
             bins=30, kde=False, color='lightblue', stat='density', edgecolor='black', label='Histogram')
plt.plot(x, gaussian, color='red', linewidth=2, label='Gaussian Curve')
plt.title('Gaussian Distribution of Price', fontsize=14)
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()
